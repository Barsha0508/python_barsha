# %%
import pandas as pd
import numpy as np

df = pd.read_csv('customer_data.csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import numpy as np
# ----> 4 df = pd.read_csv('customer_data.csv')
#       5 print(df)
#
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('customer_data.csv')
print(df)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0          01-01-2019          151200  Female  19.0         Single
# 1          02-01-2019          151201    Male  49.0         Single
# 2          03-01-2019          151202    Male  63.0        Married
# 3          04-01-2019          151203     NaN  18.0         Single
# 4          05-01-2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507       12-11-2025          153695  Female  57.0         Single
# 2508       13-11-2025          153696  Female  36.0        Married
# 2509       14-11-2025          153697    Male  22.0         Single
# 2510       15-11-2025          153698     NaN  44.0         Single
# 2511       16-11-2025          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
#display top10 records
print(df.head(10))
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0       01-01-2019          151200  Female  19.0         Single       Kansas
# 1       02-01-2019          151201    Male  49.0         Single     Illinois
# 2       03-01-2019          151202    Male  63.0        Married   New Mexico
# 3       04-01-2019          151203     NaN  18.0         Single     Virginia
# 4       05-01-2019          151204    Male  27.0         Single  Connecticut
# 5       06-01-2019          151205    Male  71.0         Single       Hawaii
# 6       07-01-2019          151206  Female  34.0        Married   New Mexico
# 7       08-01-2019          151207    Male  37.0        Married  Connecticut
# 8       09-01-2019          151208    Male  75.0        Married      Florida
# 9       10-01-2019          151209  Female  41.0        Married      Vermont
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# ...

# %%
#display last 10 records
Last_10=df.tail(10)
Last_10
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2502       07-11-2025          153690    Male  16.0         Single
# 2503       08-11-2025          153691    Male  67.0         Single
# 2504       09-11-2025          153692    Male  34.0        Married
# 2505       10-11-2025          153693    Male  54.0        Married
# 2506       11-11-2025          153694    Male  34.0         Single
# 2507       12-11-2025          153695  Female  57.0         Single
# 2508       13-11-2025          153696  Female  36.0        Married
# 2509       14-11-2025          153697    Male  22.0         Single
# 2510       15-11-2025          153698     NaN  44.0         Single
# 2511       16-11-2025          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2502       Louisiana     Basic    self-employed         PayPal      0.0
# 2503        Colorado     Basic        Employees         PayPal      0.0
# ...

# %%
#display basic operations
data.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #display basic operations
# ----> 2 data.describe()
#
# NameError: name 'data' is not defined

# %%
#display basic operations
data=df.describe()
data
# Out:
#        Transaction_ID          Age      Referal  Amount_spent
# count     2512.000000  2470.000000  2357.000000   2270.000000
# mean    152443.931131    46.637652     0.652100   1418.422577
# std        724.580482    18.186277     0.476405    878.507451
# min     151200.000000    15.000000     0.000000      2.090000
# 25%     151815.750000    32.000000     0.000000    678.192500
# 50%     152443.500000    47.000000     1.000000   1341.435000
# 75%     153071.250000    62.000000     1.000000   2038.102500
# max     153699.000000    78.000000     1.000000   2999.980000

# %%
#display mean,median,mode,standard deviation,max,min of age column
df
print("Mean:", df['Age'].mean())
print("Median:", df['Age'].median())
print("Mode:", df['Age'].mode())
print("Standard Deviation:", df['Age'].std())
print("Max:", df['Age'].max())
print("Min:", df['Age'].min())
# Out:
# Mean: 46.63765182186235
# Median: 47.0
# Mode: 0    54.0
# Name: Age, dtype: float64
# Standard Deviation: 18.186276792698017
# Max: 78.0
# Min: 15.0

# %%
#show all unique valuse from state name column
df['State_names'].nunique()
# Out:
# 50

# %%
#In age column count unique values
count_Gender =df['Gender'].value_counts()
count_Gender
# Out:
# Gender
# Female    1356
# Male      1128
# Name: count, dtype: int64

# %%
#sort data based on state name
sort_States = df['State_names'].sort_values()
sort_States
# Out:
# 617     Alabama
# 1856    Alabama
# 2443    Alabama
# 2441    Alabama
# 1023    Alabama
#          ...
# 1789    Wyoming
# 1811    Wyoming
# 1819    Wyoming
# 1844    Wyoming
# 119     Wyoming
# Name: State_names, Length: 2512, dtype: object

# %%
sorted_df = df.sort_values(by="State_names", ascending=False)
sorted_df.head(10)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 765        04-02-2021          151953  Female  44.0         Single
# 45         15-02-2019          151245    Male  70.0        Married
# 1416       17-11-2022          152604    Male  20.0         Single
# 1844       19-01-2024          153032  Female  24.0        Married
# 2463       29-09-2025          153651  Female  58.0         Single
# 1789       25-11-2023          152977  Female  36.0        Married
# 1566       16-04-2023          152754  Female  68.0        Married
# 202        22-07-2019          151390    Male  47.0         Single
# 696        27-11-2020          151884  Female  40.0        Married
# 697        28-11-2020          151885  Female  50.0         Single
#
#      State_names Segment Employees_status Payment_method  Referal  \
# 765      Wyoming   Basic    self-employed         PayPal      0.0
# 45       Wyoming   Basic     Unemployment           Card      1.0
# ...

# %%
#largest 4 age find
print("largest age", df.nlargest(4, 'Age'))
# Out:
# largest age     Transaction_date  Transaction_ID  Gender   Age Marital_status State_names  \
# 162       12-06-2019          151350  Female  78.0         Single    Michigan
# 219       08-08-2019          151407    Male  78.0        Married       Idaho
# 238       27-08-2019          151426  Female  78.0         Single     Indiana
# 254       12-09-2019          151442  Female  78.0        Married    New York
#
#      Segment Employees_status Payment_method  Referal  Amount_spent
# 162    Basic        Employees         PayPal      0.0       2555.05
# 219   Silver          workers           Card      0.0        378.43
# 238    Basic        Employees         PayPal      1.0       1264.81
# 254  Missing        Employees         PayPal      NaN       2959.54

# %%
#smallest 4 age 
print("smallest age",df.nsmallest(4,'Age'))
# Out:
# smallest age    Transaction_date  Transaction_ID Gender   Age Marital_status  \
# 33       03-02-2019          151233   Male  15.0        Married
# 54       24-02-2019          151254   Male  15.0        Married
# 62       04-03-2019          151262   Male  15.0        Married
# 67       09-03-2019          151262   Male  15.0        Married
#
#        State_names Segment Employees_status Payment_method  Referal  \
# 33        Missouri    Gold    self-employed           Card      1.0
# 54        Illinois   Basic        Employees           Card      1.0
# 62  South Carolina   Basic    self-employed          Other      1.0
# 67  South Carolina   Basic    self-employed          Other      1.0
#
#     Amount_spent
# 33        628.93
# 54       2690.18
# 62        790.10
# 67        790.10
